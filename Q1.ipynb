# %% [markdown]
# ##Explain the key features of Python that makes it a popular choice for programming.

# %% [markdown]
# ###Features of programming:
# python has many features that make it a populer and powerful language for various application that are:
#
# 1. Free and open source : python is freely available at the official website and the source code is also accessible to the public.
#
# 2. Easy to code and read: python has a simple and clear syntex that is easy to learn and write.Python uses indentation to define code blocks, rather than semicolons or brackets so it makes debugging easier.
#
# 3. There are 1,37,000 libraries are available that makes very Easy to Code in python.
# 4.Python has a very large community.
# 5. While coding in python the code are easily to understandable and Easy to debug.
# 6. Python is a high-level programming language.
